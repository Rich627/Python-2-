# %%
import requests as rq
user = 'Rich0912'
password = 'leoalice02100709'
response = rq.get("https://api.github.com/user/repos", auth = (user,password))
response
# Out:
# <Response [401]>

# %%
#Cookie 設定
import requests as rq

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
#解決cookie問題 從inspect中檢查application右邊有cookie
cookie = {'over18':'1'}

url = rq.get(url, cookies = cookie)
if url.status_code == 200:
    print(url.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# ...

# %%
#下載網頁內容
from bs4 import BeautifulSoup

url = 'https://fchart.github.io/ML/Surveys.html'
html = rq.get(url)


sp = BeautifulSoup(html.text, 'lxml')
tags = sp('div')

sp.title
# Out:
# <title>測試資料擷取的HTML網頁</title>

# %%
#爬大樂透號碼

import requests as rq
from bs4 import BeautifulSoup

url = 'https://www.taiwanlottery.com.tw/lotto/lotto649/history.aspx'

html = rq.get(url)
#if html.status_code == 200:
    #print('Successful')
sp = BeautifulSoup(html.text, 'lxml')

tags = sp('tr')
tags[6]
# Out:
# <tr>
# <td class="td_org2" colspan="2"> 大小順序 </td>
# <td class="td_w font_black14b_center"><span id="Lotto649Control_history_dlQuery_No1_0">02</span></td>
# <td class="td_w font_black14b_center"><span id="Lotto649Control_history_dlQuery_No2_0">11</span></td>
# <td class="td_w font_black14b_center"><span id="Lotto649Control_history_dlQuery_No3_0">25</span></td>
# <td class="td_w font_black14b_center"><span id="Lotto649Control_history_dlQuery_No4_0">26</span></td>
# <td class="td_w font_black14b_center"><span id="Lotto649Control_history_dlQuery_No5_0">27</span></td>
# <td class="td_w font_black14b_center"><span id="Lotto649Control_history_dlQuery_No6_0">35</span></td>
# <td class="td_w font_red14b_center" colspan="2"><span id="SuperLotto638Control_history1_dlQuery_No7_0"><span id="Lotto649Control_history_dlQuery_SNo_0">10</span></span> </td>
# </tr>
